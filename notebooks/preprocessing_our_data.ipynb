# %%
from pathlib import Path
import pandas as pd

# %%
MAIN_PATH  =  Path('D:\data\VTB\moretech')

# %%
tg_path = MAIN_PATH / 'tg-channels.csv'

# %%
tg_df = pd.read_csv(tg_path)
tg_df
# Out:
#       Unnamed: 0                                url  \
# 0              0     https://t.me/netipichniy_buh/5
# 1              1     https://t.me/netipichniy_buh/6
# 2              2     https://t.me/netipichniy_buh/7
# 3              3     https://t.me/netipichniy_buh/8
# 4              4     https://t.me/netipichniy_buh/9
# ...          ...                                ...
# 2328        2328  https://t.me/gendirector_maxim/53
# 2329        2329  https://t.me/gendirector_maxim/54
# 2330        2330  https://t.me/gendirector_maxim/55
# 2331        2331  https://t.me/gendirector_maxim/56
# 2332        2332  https://t.me/gendirector_maxim/57
#
#                                                   title  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# ...

# %%
tg_df.text[0]
# Out:
# '[\u200b\u200b](https://telegra.ph/file/8774505ca2814d3612b0c.jpg)💡Рассмотрим отчет «Обороты между субконто». Им мало кто пользуется, однако с его помощью можно выбирать и анализировать различную информацию, используя любые комбинации аналитики (субконто счетов). \n\nНапример, посмотреть какие товары поступили от каких поставщиков, или какие ТМЦ были куплены подотчетным лицом за определенный промежуток времени. Отчет позволяет устанавливать отбор, задавать параметры группировки информации. Находится он в разделе «Отчеты» - «Обороты между субконто».\n\nНапример, чтобы проанализировать поступающую номенклатуру по поставщикам, в отчете нужно выбрать вид субконто - «Контрагенты», корреспондирующее субконто - «Номенклатура», далее «Сформировать». При такой настройке в отчет включаются и покупатели (счет 62), и поставщики (счет 60).\n\nДля формирования отчета только по поставщикам нужно перейти по кнопке «Показать настройки» - вкладка «Отбор», в табличную часть добавить поле «Счет» равно 6
# ...
